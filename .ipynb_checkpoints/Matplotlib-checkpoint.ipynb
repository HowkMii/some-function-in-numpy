# %%
from matplotlib import pyplot as plt

# %%
plt.plot([3,4,5],[7,8,9])

# %%
plt.plot([1,2,3],[5,1,7])

# %%
myarray1 = [300,400,4]

# %%
myarray2 = [6,150,400]

# %%
plt.plot(myarray1,myarray2)

# %%
plt.plot(myarray1,myarray2)
plt.title("Two arrays")
plt.ylabel("abdelhakim")
plt.xlabel("howkmii")
plt.show()

# %%
myarray3 = [1,2,3,4,1,6]
plt.plot(myarray3)
plt.title("myarray3")
plt.ylabel("daiki")
plt.xlabel("Numbers")
plt.show()

# %%
myarray4 = [1,2,3,4,5,6]
myarray5 = [11,7,3,8,5,16]
plt.plot(myarray4,myarray5 ,'ro')
plt.title("myarray4 & 5")
plt.ylabel("y axis")
plt.xlabel("x axis")
plt.show()
